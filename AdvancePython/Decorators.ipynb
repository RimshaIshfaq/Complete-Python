# %% [markdown]
# ## Decorators
#
# Decorators are a powerful and flexible feature in Python that aloows you to modify the behavior of a function or class method. They are commonly used to add functionality to functions or methods without modifying their actual code.

# %%
## function copy
## closures
## decorators

# %%
## function copy

def welcome():
    return "Hi guys, make your dream life <3"

welcome()
# Out:
# 'Hi guys, make your dream life <3'

# %%
wel = welcome
print(wel())

del welcome
print(wel())
# Out:
# Hi guys, make your dream life <3
# Hi guys, make your dream life <3

# %%
## closures function

def main_welcome(msg):
    def sub_welcome_method():
        print("Welcome to python world")
        print(msg)
        print("Have a nice day")
    return sub_welcome_method()

# %%
main_welcome("Yippee, I am learning python")
# Out:
# Welcome to python world
# Yippee, I am learning python
# Have a nice day

# %%
def main_welcome(func, list):
    def sub_welcome_method():
        print("Welcome to python world")
        print(func(list))
        print("Have a nice day")
    return sub_welcome_method()

# %%
main_welcome(len, [1,2,3,4,5])
# Out:
# Welcome to python world
# 5
# Have a nice day

# %%
### Decorator

def main_welcome(func):

    def sub_welcome_method():
        print("Welcome to python world")
        func()
        print("Have a nice day")
    return sub_welcome_method()

# %%
def course_introduction():
    print("This is an advanced python course")

course_introduction()
# Out:
# This is an advanced python course

# %%
main_welcome(course_introduction)
# Out:
# Welcome to python world
# This is an advanced python course
# Have a nice day

# %%
@main_welcome
def course_introduction():
    print("This is an advanced python course")
# Out:
# Welcome to python world
# This is an advanced python course
# Have a nice day

# %%
## Decorator

def my_decorator(func):
    def wrapper():
        print("Something is happening before the function is called.")
        func()
        print("Something is happening after the function is called.")
    return wrapper

# %%
@my_decorator
def say_whee():
    print("Whee!")

# %%
say_whee()
# Out:
# Something is happening before the function is called.
# Whee!
# Something is happening after the function is called.

# %%
## Decorators with Arguments
def repeat(n):
    def decorator(func):
        def wrapper(*args, **kwargs):
            for _ in range(n):
                func(*args, **kwargs)
        return wrapper
    return decorator

# %%
@repeat(3)
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Hello!
# Hello!
# Hello!

# %% [markdown]
# ## Conclusion:
#
# Decorators are a powerful tool in Python for extending and modifying the behavior of functions and methods. They provide a clean and readable way to add functionality such as logging, timing, access control and more without changing the original code. Understanding and using decorators effectively can significantly enhance your Python Programming Skills.
