# %% [markdown]
# ## Tuples

# %% [markdown]
# #### Video Outline:
#
# - Introduction to Tuples
# - Creating Tuples
# - Accessing Tuple Elements
# - Tuple Operations
# - Immutable Nature of Tuples
# - Tuple Methods
# - Packing and Unpacking Tuples
# - Nested Tuples
# - Practical Examples and Common Errors
#
# #### Introduction to Tuples
#
# Tuples are ordered collections of items that are immutable. They are similar to lists, but their immutability makes them different.

# %%
# creating a tuple
empty_tuple = ()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst = list()
print(type(lst))
tpl = tuple()
print(type(tpl))
# Out:
# <class 'list'>
# <class 'tuple'>

# %%
numbers = tuple([1, 2, 3, 4, 5])
print(numbers)
# Out:
# (1, 2, 3, 4, 5)

# %%
# mixed tuple
mixed_tuple = (1, "Hello", 3.14, [1, 2, 3], (4, 5))
print(mixed_tuple)
# Out:
# (1, 'Hello', 3.14, [1, 2, 3], (4, 5))

# %%
# Accessing elements in a tuple
numbers
# Out:
# (1, 2, 3, 4, 5)

# %%
print(numbers[2])
print(mixed_tuple[1])
# Out:
# 3
# Hello

# %%
# Tuple Operations

concatenation = numbers + mixed_tuple
print(concatenation)
# Out:
# (1, 2, 3, 4, 5, 1, 'Hello', 3.14, [1, 2, 3], (4, 5))

# %%
mixed_tuple*3
# Out:
# (1,
#  'Hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'Hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5),
#  1,
#  'Hello',
#  3.14,
#  [1, 2, 3],
#  (4, 5))

# %%
## Immutable Nature Of Tuples
## Tuples are immutable, meaning their elements cannot be changed once assigned.

lst = [1,2,3,4,5]
print(lst)

lst[1] = "Rimsha"
print(lst)
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Rimsha', 3, 4, 5]

# %%
numbers[1] = "Rimsha"  # This will raise a TypeError since tuples are immutable.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 numbers[1] = "Rimsha"  # This will raise a TypeError since tuples are immutable.
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Tuple Methods
print(numbers.count(1))
print(numbers.index(3))
# Out:
# 1
# 2

# %%
# packing and unpacking tuple
# packing
packed_tuple = 1, "Hello", 3.14
print(packed_tuple)
# Out:
# (1, 'Hello', 3.14)

# %%
# unpacking a tuple
a, b, c = packed_tuple
print(a)
print(b)    
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
# unpacking with *

numbers = (1, 2, 3, 4, 5)
a, *b, c = numbers
print(a)  # Output: 1   
print(b)
print(c)
# Out:
# 1
# [2, 3, 4]
# 5

# %%
# Nested tuple

nested_tuple = ((1,2,3),("a","b","c"),(True, False))

# Access the elements inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
# Iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item, end="")
    print()
# Out:
# 123
# abc
# TrueFalse

# %% [markdown]
# #### Conclusion
# Tuples are versatile and useful in many real-world scenarios where an immutable and ordered collection of items is required. They are commonly used in data structures, function arguments and return values, and as dictionary keys. Understanding how to leverage tuples effectively can improve the efficiency and readability of your Python code.
