# %% [markdown]
# ## File Path

# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# c:\codingprojects\CompletePythonforDataScience\FileHandling

# %%
# create a new directory

new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created successfully.")
# Out:
# Directory 'package' created successfully.

# %%
# Listing all files and directories in the current directory

items = os.listdir(cwd)
print(items)
# Out:
# ['destination.txt', 'example.bin', 'example.txt', 'fileoperation.ipynb', 'filepath.ipynb', 'package']

# %%
## joining paths

dir_name = "folder"
file_name = "file.txt"

full_path = os.path.join(dir_name, file_name)
print(full_path)

dir_path = os.path.join(cwd, dir_name)
print(dir_path)
# Out:
# folder\file.txt
# c:\codingprojects\CompletePythonforDataScience\FileHandling\folder

# %%
path = 'example1.txt'
if os.path.exists(path):
    print(f"The file '{path}' exists.")
else:
    print(f"The file '{path}' does not exist.")
# Out:
# The file 'example1.txt' does not exist.

# %%
# checking if a path is a file or a directory

import os
path = 'example1.txt'

if os.path.isfile(path):
    print(f"The path '{path}' is a file.")
elif os.path.isdir(path):
    print(f"The path '{path}' is a directory.")
else:
    print(f"The path '{path}' does not exist.")
# Out:
# The path 'example1.txt' does not exist.

# %%
# getting the absolute path

relative_path = 'example1.txt'
absolute_path = os.path.abspath(relative_path)
print(f"Absolute path: {absolute_path}")
# Out:
# Absolute path: c:\codingprojects\CompletePythonforDataScience\FileHandling\example1.txt
