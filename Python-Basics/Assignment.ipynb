# %% [markdown]
# # Lesson 1.2: Python Basics
# ## Topics Covered:
# - Syntax and Semantics
# - Variables and Data Types
# - Basic Operators (Arithmetic, Comparison, Logical)

# %% [markdown]
# ## 1. Syntax and Semantics
#
# **Question 1:** Write a Python program to print "Hello, World!".

# %%
# Your code here
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# **Question 2:** Write a Python program that takes a user input and prints it.

# %%
# Your code here
user_input = input("Enter your name here: ")
print(user_input)
# Out:
# rimsha

# %% [markdown]
# **Question 3:** Write a Python program to check if a number is positive, negative, or zero.

# %%
# Your code here
num = int(input("Enter a number here: "))

if num==0:
    print("The number is zero")
elif num>0:
    print("The number is positive") 
else:
    print("The number is negative")
# Out:
# The number is positive

# %% [markdown]
# **Question 4:** Write a Python program to find the largest of three numbers.

# %%
# Your code here

a = float(input("Enter a number here as a: "))
b = float(input("Enter another number here as b: "))
c = float(input("Enter another number here as c: "))

if a >= b and a >=c:
    print ("The largest number is a: ", a)
elif b >=a and b >=c:
    print ("The largest number is b: ", b)
else:
    print ("The largest number is c: ", c)
# Out:
# The largest number is c:  7.0

# %% [markdown]
# **Question 5:** Write a Python program to calculate the factorial of a number.

# %%
# Your code here
num = int(input("Enter a number here: "))

fact = 1

for i in range(1, num+1):
    fact = fact*i
    

print(fact)
# Out:
# 6

# %% [markdown]
# ## 2. Variables and Data Types
#
# **Question 6:** Create variables of different data types: integer, float, string, and boolean. Print their values and types.

# %%
# Your code here

age = 23
height = 5.2
name = "Rimsha"
is_strudent = True

print(age)
print(type(age))
print(height)
print(type(height))
print(name) 
print(type(name))
print(is_strudent)
print(type(is_strudent))
# Out:
# 23
# <class 'int'>
# 5.2
# <class 'float'>
# Rimsha
# <class 'str'>
# True
# <class 'bool'>

# %% [markdown]
# **Question 7:** Write a Python program to swap the values of two variables.

# %%
# Your code here

a = int(input("Enter a number here as a: "))
b = int(input("Enter another number here as b: "))

a, b = b, a
print("Value of a after swapping: ", a)
print("Value of b after swapping: ", b)
# Out:
# Value of a after swapping:  3
# Value of b after swapping:  2

# %% [markdown]
# **Question 8:** Write a Python program to convert Celsius to Fahrenheit.

# %%
# Your code here

temp_C = float(input("Enter temperature in Celsius here: "))

def to_Fahrenheit(temp_C):
    temp_F = (temp_C * 9/5) + 32
    return temp_F

result = to_Fahrenheit(temp_C)
print(result)
# Out:
# 149.0

# %% [markdown]
# **Question 9:** Write a Python program to concatenate two strings.

# %%
# Your code here
first_name = "Rimsha"
last_name = "Ishfaq"

full_name = first_name + " " + last_name
print(full_name)
# Out:
# Rimsha Ishfaq

# %% [markdown]
# **Question 10:** Write a Python program to check if a variable is of a specific data type.

# %%
# Your code here

age = input("Enter your age here: ")

if type(age) == int:
    print("The input is an integer")
else:
    print("The input is not an integer")
# Out:
# The input is not an integer

# %% [markdown]
# ## 3. Basic Operators (Arithmetic, Comparison, Logical)
#
# **Question 11:** Write a Python program to perform arithmetic operations: addition, subtraction, multiplication, and division.

# %%
# Your code here
num1 = 22
num2 = 31

addition = num1 + num2
subtraction = num1 - num2
multiplication = num1 * num2
division = num1 / num2

print("Addition:", addition)
print("Subtraction:", subtraction)          
print("Multiplication:", multiplication)
print("Division:", division)
# Out:
# Addition: 53
# Subtraction: -9
# Multiplication: 682
# Division: 0.7096774193548387

# %% [markdown]
# **Question 12:** Write a Python program to demonstrate comparison operators: equal to, not equal to, greater than, less than.

# %%
# Your code here

num1 = 33
num2 = 11

print(num1 == num2)
print(num1 != num2)
print(num1 > num2)
print(num1 < num2)
# Out:
# False
# True
# True
# False

# %% [markdown]
# **Question 13:** Write a Python program to demonstrate logical operators: and, or, not.

# %%
# Your code here

bol1 = True
bol2 = False
bol3 = True

print(bol1 and bol2)
print(bol1 and bol3)
print(bol1 or bol2)
print(bol1 or bol3)
print(not bol1)
print(not bol2)
# Out:
# False
# True
# True
# True
# False
# True

# %% [markdown]
# **Question 14:** Write a Python program to calculate the square of a number.

# %%
# Your code here

num = int(input("Enter number here: "))

def square(num):
    return num**2

result = square(num)
print(result)
# Out:
# 9

# %% [markdown]
# **Question 15:** Write a Python program to check if a number is even or odd.

# %%
# Your code here
num = int(input("Enter a number here: "))

if num%2==0:
    print("The number is even")
else:
    print("The number is odd")
# Out:
# The number is odd

# %% [markdown]
# **Question 16:** Write a Python program to find the sum of the first n natural numbers.

# %%
# Your code here

n = int(input("Enter a number here: "))

sum = 0
for i in range(1, n+1):
    sum = sum + i

print(sum)
# Out:
# 15

# %% [markdown]
# **Question 17:** Write a Python program to check if a year is a leap year.

# %%
# Your code here

year = int(input("Enter a year here: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("The year is a leap year")
else:
    print("The year is not a leap year")
# Out:
# The year is a leap year

# %% [markdown]
# **Question 18:** Write a Python program to reverse a string.

# %%
# Your code here
str = input("Enter a string: ")
reversed_str = ""

for char in str:
    reversed_str = char + reversed_str

print(reversed_str)
# Out:
# ahsmir

# %% [markdown]
# **Question 19:** Write a Python program to check if a string is a palindrome.

# %%
# Your code here
# palindrome string is a string that once reversed is the same as the original string 
# like "madam" or "racecar"

str = input("Enter a string: ")
reversed_str = ""

for char in str:
    reversed_str = char + reversed_str

if reversed_str == str:
    print("The string is a palindrome")
# Out:
# The string is a palindrome

# %% [markdown]
# **Question 20:** Write a Python program to sort a list of numbers in ascending order.

# %%
# Your code here

numbers = [5, 7, 2, 9, 4, 1]
sorted_numbers = sorted(numbers)
print(sorted_numbers)
# Out:
# [1, 2, 4, 5, 7, 9]
