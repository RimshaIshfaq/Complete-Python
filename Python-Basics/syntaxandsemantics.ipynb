# %% [markdown]
# ## Syntax and Semantics in Python

# %% [markdown]
# #### Outline:
#
# - Single line Comments and multiline comments
# - Definition of Syntax and Semantics
# - Basic Syntax Rules in Python
# - Understanding Semantics in Python
# - Common Syntax Errors and How to Avoid Them
# - Practical Code Examples

# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code.
#
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. It is about what the code is supposed to do when it runs.

# %%
#basic rules
#case senstivity of python - python is case sensitive language. 
# It means that uppercase and lowercase letters are treated as different characters. 

name ="Rimsha"
Name = "ishfaq"

print(name)
print(Name)
# Out:
# Rimsha
# ishfaq

# %%
# Indentation
# In Python, indentation is used to define blocks of code.
# It is important to use consistent indentation (usually 4 spaces) to avoid syntax errors.

age = 25
if age >= 18:
    print("You are an adult.")
else:
    print("You are a minor.")
# Out:
# You are an adult.

# %%
# comments
# use # for single line comments
# This is a single line comment
# use triple quotes for multi-line comments

"""
This is a multi-line comment.
It can span multiple lines.
"""
# Out:
# '\nThis is a multi-line comment.\nIt can span multiple lines.\n'

# %%
# Line continuition
# Use backslask (\) to continue a line of code onto the next line.

num = 1 + 2 + 3 +\
        4 + 5 + 6
print(num)
# Out:
# 21

# %%
# Multiple statements on a single line
# Use a semicolon (;) to separate multiple statements on a single line.

x=5;y=6;z=7
print(x,y,z)
# Out:
# 5 6 7

# %%
# Type Inference
name = "Rimsha" #it is a string
age = 25 #it is an integer

print(name)
print(age)

print(type(name))
print(type(age))
# Out:
# Rimsha
# 25
# <class 'str'>
# <class 'int'>

# %% [markdown]
# #### Conclusion
# Syntax is the "form" and semnatics is the "meaning".
# understanding synatx and semnatics is very important to understand to write code properly.
